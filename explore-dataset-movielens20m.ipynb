# %%
# importing pandas library and making some settings.
import pandas as pd
pd.set_option('display.expand_frame_repr', False)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
# reading datasets.
movie = pd.read_csv('/kaggle/input/movielens-20m-dataset/movie.csv')
rating = pd.read_csv('/kaggle/input/movielens-20m-dataset/rating.csv')
genome_scores = pd.read_csv('/kaggle/input/movielens-20m-dataset/genome_scores.csv')
tag_df = pd.read_csv('/kaggle/input/movielens-20m-dataset/tag.csv')

# %%
genome_scores.shape
# Out:
# (11709768, 3)

# %%
tag_df.shape
# Out:
# (465564, 4)

# %%
genome_scores2 = genome_scores[genome_scores.relevance >= 0.5]
genome_scores2.shape
# Out:
# (460090, 3)

# %%
movie.head()
# Out:
#    movieId                               title                                       genres
# 0        1                    Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                      Jumanji (1995)                   Adventure|Children|Fantasy
# 2        3             Grumpier Old Men (1995)                               Comedy|Romance
# 3        4            Waiting to Exhale (1995)                         Comedy|Drama|Romance
# 4        5  Father of the Bride Part II (1995)                                       Comedy

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
rating.userId.unique()
# Out:
# array([     1,      2,      3, ..., 138491, 138492, 138493])

# %%
rating[rating.userId == 100].sort_values(by = 'rating').head()
# Out:
#        userId  movieId  rating            timestamp
# 11085     100      586     1.0  1996-06-25 16:32:37
# 11057     100      185     2.0  1996-06-25 16:23:45
# 11073     100      427     2.0  1996-06-25 16:36:08
# 11075     100      434     2.0  1996-06-25 16:23:18
# 11079     100      500     2.0  1996-06-25 16:30:44

# %%
genome_scores2[genome_scores2.movieId == 18].sort_values(by = [
                                "relevance", 
                                "tagId"
                                ], ascending = False)
# Out:
#        movieId  tagId  relevance
# 19910       18    735    0.92675
# 20147       18    972    0.91200
# 19701       18    526    0.89475
# 20184       18   1009    0.81250
# 20156       18    981    0.80400
# 20279       18   1104    0.77825
# 19854       18    679    0.76475
# 19917       18    742    0.75850
# 19643       18    468    0.75125
# 19477       18    302    0.70275
# 20226       18   1051    0.70125
# 19464       18    289    0.67375
# 19193       18     18    0.66750
# 19640       18    465    0.65200
# 19395       18    220    0.64350
# 20000       18    825    0.63975
# 19461       18    286    0.62900
# 19405       18    230    0.61800
# 20146       18    971    0.61550
# 19344       18    169    0.61550
# 19627       18    452    0.61450
# 19647       18    472    0.61400
# 20225       18   1050    0.61225
# 19962       18    787    0.59200
# 20246       18   1071    0.59175
# 20183       18   1008    0.58950
# 19571       18    396    0.58525
# 19450       18    275    0.57950
# 19441       18    266    0.57900
# 19680       18    505    0.57850
# 20224       18   1049    0.57750
# 20288       18   1113    0.57575
# 19316       18    141    0.56050
# 20167       18    992    0.55450
# 19687       18    512    0.55425
# 19620       18    445    0.55275
# 19321       18    146    0.54625
# 20239       18   1064    0.53400
# 19415       18    240    0.52500
# 19367       18    192    0.52325
# 19498       18    323    0.52225
# 19314       18    139    0.51900
# 373716  117151        1                                               toys  2015-02-23 18:15:24
# 228121   68767        1                                          very good  2006-02-19 19:11:40
# 90046    22483        1                                 villian hurts toys  2008-07-21 23:08:07
# 374083  117270        1                                       voice acting  2012-05-16 23:01:20
# 159765   46880        1                                  want to see again  2006-05-09 20:30:50
# 48702    11081        1                                               warm  2007-03-07 21:47:32
# 25503     6233        1                                              witty  2013-12-15 03:52:56
# 377714  119367        1                                              witty  2009-05-07 18:36:47
# 427306  128426        1                                              witty  2009-10-21 10:49:54
# 422991  127489        1                                              witty  2010-11-15 21:58:54
# 209331   61599        1                                              witty  2010-11-26 05:42:44
# 418199  125482        1                                              witty  2010-09-20 20:34:04
# 48703    11081        1                                              witty  2007-03-07 21:47:57
# 139695   39707        1                                              witty  2009-05-31 05:42:07
# 61474    14088        1                                              witty  2011-08-28 20:09:44
# 290543   88055        1                                              witty  2012-06-12 20:12:58
# 374084  117270        1                                              witty  2012-05-16 23:01:20
# 340064  103125        1                                              witty  2011-04-18 23:10:40
# 429318  129903        1                                              witty  2010-04-17 00:58:55
# 115230   28780        1                                              witty  2010-05-18 15:49:27
# 138097   38334        1                                             ya boy  2006-02-20 03:13:53
# 109547   27735        1                                          é˜®ä¸€é¸£  2006-03-22 13:57:33

# %% [markdown]
# ## Pruning tags

# %%
tag_list = list(tag_df.tag.unique())
len(tag_list)
# Out:
# 38644

# %%
tag_list2 =[]
for tag in tag_list:
    if isinstance(tag, str):
        tag_words = tag.split(" ")
        use = True
        if len(tag_words) > 2:
            # Remove tags with more tahn two words
            use = False
        if not tag.isalnum():
            # Remove tags with special characters
            use = False
#         if len(tag_words) == 1 and len(tag_words[0]) == 1:
#             # remove tags with a single alphabet
#             use = False
        if use:
            tag_list2.append(tag)
# Create unique tag set
tag_set = set(tag_list2)
len(tag_set)
# Out:
# 9165

# %%
tag_set
# Out:
# {'Favelas',
#  'morbid',
#  'Chicago',
#  'Xerxes',
#  'wit',
#  'uncompromising',
#  'young',
#  'fight',
#  'chipmunks',
#  'isolation',
#  'storm',
#  'catholic',
#  'scooter',
#  'stirring',
#  'water',
#  'bee',
#  'Atheism',
#  'hoax',
#  'AVORRIDA',
#  'cult',
#  'mockumentry',
#  'whistleblower',
#  'dwarfs',
#  'bird',
#  'boring',
#  'Gypsy',
#  'Panama',
#  'cougars',
#  'sociopathic',
#  'karate',
#  'gnosticism',
#  'Harlem',
#  'Chad',
#  'duality',
#  'Oedipus',
#  'Novelist',
#  'Wittgenstein',
#  'wholesome',
#  'Hostages',
#  'anticommunists',
#  'life',
#  'vatican',
#  'cineastic',
#  'Criticism',
#  'Partisans',
#  'humanistic',
#  'Revamp',
#  'Stoner',
#  'perverted',
#  'zegist',
#  'optimistic',
#  'Eccentric',
#  'tough',
#  'betrayl',
#  'Resolution',
#  'austrian',
#  'typical',
#  'Redux',
#  'ocean',
#  'confession',
#  'architecture',
#  'ignorance',
#  'narration',
#  'growth',
#  'Greenwich',
#  'convent',
#  'matchmaking',
#  'Rose',
#  'minnsota',
#  'jeffrey',
#  'drought',
#  'indoctrination',
#  'Words',
#  'grandstand',
#  'taboo',
#  'Grey',
#  'trolls',
#  'friends',
#  'Touching',
#  'trick',
#  'poorness',
#  'lyrical',
#  'Norwegian',
#  'malaria',
#  'gayish',
#  'carbonite',
#  'fantacy',
#  'samurai',
#  'country',
#  'seeout',
#  'Fosse',
#  'sleaze',
#  'torture',
#  'Nakedness',
#  'silhouettes',
#  'harlem',
#  'THEATER',
#  'Adrenaline',
#  'hooker',
#  'thong',
#  'orgy',
#  'idaho',
#  'ETA',
#  'inicom',
#  'afi100',
#  'Clinton',
#  'immigrants',
#  'retro',
#  'Peron',
#  'anthropomorphism',
#  'canoeing',
#  'l',
#  'unfair',
#  'fable',
#  'hockey',
#  'infantile',
#  'nonconformity',
#  'spelunking',
#  'unsafisfying',
#  'vulnerability',
#  'peasants',
#  'romanc',
#  'boheme',
#  'mutiny',
#  'synagogue',
#  'Photo',
#  'marines',
#  'tech',
#  'cliques',
#  'padding',
#  'dreary',
#  'ninja',
#  'curling',
#  'innuendo',
#  'woodstock',
#  'darfur',
#  'robotics',
#  'werewolf',
#  'compilation',
#  'pleasant',
#  'odysseus',
#  'winnings',
#  'intellegent',
#  'Mario',
#  'punks',
#  'puka',
#  'Aerospace',
#  'mayan',
#  'Finns',
#  'peeta',
#  'dani2008',
#  'poor',
#  'Republic',
#  'bride',
#  'continuity',
#  'diner',
#  'Legal',
#  'Target',
#  'Paradox',
#  'botany',
#  'madc',
#  'Rainstorm',
#  'GLBT',
#  'arch',
#  'inimitable',
#  'DA',
#  'swimming',
#  'macross',
#  'sheep',
#  'Reenactment',
#  'Screenplay',
#  'promise',
#  'bailiff',
#  'existentialist',
#  'bluegrass',
#  'Skeletor',
#  'Portuguese',
#  'Unfunny',
#  'reconciling',
#  'outrageous',
#  'Dreyer',
#  'india',
#  'Battles',
#  'nostalgia',
#  'steamboats',
#  'gangsterfilm',
#  'mossad',
#  'unconvincing',
#  'Moon',
#  'girl',
#  'body',
#  'moneypenny',
#  'shoa',
#  'sassy',
#  'strategy',
#  'baffling',
#  'dialog',
#  'dingy',
#  'president',
#  'individualism',
#  'catapult',
#  'metafilm',
#  'gargoyles',
#  'snob',
#  'institutions',
#  'Uggie',
#  'Insanity',
#  'lulz',
#  'creationism',
#  'Hedonism',
#  'solitude',
#  'imagine',
#  'ex',
#  'Lamer',
#  'Satan',
#  'Spells',
#  'foxes',
#  'avi',
#  'Altman',
#  'spirits',
#  'ABBA',
#  'Fischhorror',
#  'rund',
#  'vocabullary',
#  'party',
#  'tender',
#  'sleepy',
#  'fisting',
#  'robbers',
#  'powers',
#  'SEAL',
#  'kamikaze',
#  'psycodelic',
#  'hooligans',
#  'speakeasy',
#  'nuda',
#  'affair',
#  'jilted',
#  'exploration',
#  'surrogate',
#  'Gratuitous',
#  'zoo',
#  'weapons',
#  'Barbarian',
#  'impressive',
#  'robot',
#  'beautiful',
#  'trust',
#  'opossums',
#  'moped',
#  'Ital',
#  'Crossdressing',
#  'lovecraftian',
#  'Dull',
#  'Zimbabwe',
#  'pacifist',
#  'straightforward',
#  'kuenstlerroman',
#  'patient',
#  'multilayered',
#  'neorealism',
#  'marine',
#  'touching',
#  'rapey',
#  'critical',
#  'multifaceted',
#  'Sexual',
#  'finance',
#  'Galactica',
#  'ronin',
#  'melee',
#  'complot',
#  'ring',
#  'skinheads',
#  'collectible',
#  'witty',
#  'Plastics',
#  'mixtape',
#  'owls',
#  'italy',
#  'Amtrak',
#  'Wolverine',
#  'Fictional',
#  'flight',
#  'alaska',
#  'Ukraine',
#  'novelist',
#  'subordination',
#  'Faries',
#  'mkv',
#  'guilt',
#  'disaster',
#  'Gilliam',
#  'antichrist',
#  'shock',
#  'schizophrenia',
#  'refugees',
#  'unwatchable',
#  'gentle',
#  'Long',
#  'unscary',
#  'Acting',
#  'presentation',
#  'finnish',
#  'pyschology',
#  'Portugal',
#  'Siegfried',
#  'Queen',
#  'autumnal',
#  'BSDM',
#  'rumor',
#  'Russians',
#  'dutch',
#  'dare',
#  'assassination',
#  'consciousness',
#  'insularity',
#  'Mediocre',
#  'draggy',
#  'harmonica',
#  'blacklist',
#  'Pulp',
#  'Competition',
#  'toplist10',
#  'Screwball',
#  'ldschoolcool',
#  'realtime',
#  'montages',
#  'Tragedy',
#  'strangulation',
#  'geese',
#  'Baghdad',
#  'cards',
#  'Rave',
#  'Stylish',
#  'apprenticeship',
#  'homelessness',
#  'hulk',
#  'moth',
#  'cast',
#  'insubordination',
#  'inappropriate',
#  'skinnydipping',
#  'melancholy',
#  'stamps',
#  'sdf',
#  'kafkaesque',
#  'sexuality',
#  'Sickening',
#  'circus',
#  'yakuza',
#  'entrepreneurs',
#  'Katottava',
#  'orgiginal',
#  'fire',
#  'Florida',
#  'auteur',
#  'Hiroshima',
#  'automata',
#  'ruthless',
#  'TOSTON',
#  'climate',
#  'KIDNAPPING',
#  'data',
#  'cynical',
#  'Maserati',
#  'NATO',
#  'Caribbean',
#  'Maffia',
#  'revolt',
#  'Gag',
#  'dragged',
#  'estrangeinro',
#  'pornography',
#  'Inspiring',
#  'millionare',
#  'prequel',
#  'kickboxing',
#  'child',
#  'hasty',
#  'London',
#  'homophobia',
#  'grainy',
#  'european',
#  'unfulfilling',
#  'medschool',
#  'caravan',
#  'Program',
#  'unremarkable',
#  'traveling',
#  'G',
#  'play',
#  'colonialism',
#  'grindhouse',
#  'frontier',
#  'narf',
#  'freedom',
#  'Weihnachtsfilm',
#  'moonshine',
#  'sterility',
#  'mentiras',
#  'zeppelin',
#  'Gangland',
#  'demise',
#  'bioterrorism',
#  'shiny',
#  'katana',
#  'Antihero',
#  'hearthwarming',
#  'welsh',
#  'cheesy',
#  'MATCHMAKERS',
#  'Rihanna',
#  'elitism',
#  'company',
#  'Lobbyism',
#  'Playlist',
#  'moose',
#  'Linkoping',
#  'hashish',
#  'texas',
#  'uranium',
#  'stargate',
#  'cringe',
#  'onirism',
#  'captivity',
#  'flying',
#  'transvestites',
#  'inside',
#  'Nirvana',
#  'Bullshit',
#  'Emperor',
#  'FORM',
#  'existensial',
#  'Isis',
#  'epic',
#  'storry',
#  'domination',
#  'lonliness',
#  'disturbing',
#  'reflection',
#  'Batman',
#  'Pointless',
#  'cheats',
#  'Goemon',
#  'landscape',
#  'rickyism',
#  'aztec',
#  'delicious',
#  'retarted',
#  'hobbit',
#  'authenticity',
#  'Christian',
#  'Barcelona',
#  'understated',
#  'Retirement',
#  'unsettling',
#  'tierhorror',
#  'Biopic',
#  'dusty',
#  'steamy',
#  'Masons',
#  'surgery',
#  'literary',
#  'finland',
#  'sociolagy',
#  'enthralling',
#  'masks',
#  'Mamet',
#  'sentiment',
#  'malik',
#  'Rameshwaram',
#  'recycling',
#  'furious',
#  'dormitory',
#  'adventurous',
#  'lottery',
#  'elves',
#  'Creative',
#  'traumatic',
#  'Memphis',
#  'sentimentality',
#  'expedition',
#  'raccoon',
#  'Intense',
#  'spiral',
#  'gunfights',
#  'nonsensical',
#  'marathons',
#  'incest',
#  'Trieste',
#  'boomerang',
#  'Hulk',
#  'twists',
#  'margaritas',
#  'Atreyu',
#  'Diary',
#  'raunch',
#  'Advertising',
#  'Apatow',
#  'holes90s',
#  'Antisemitism',
#  'degrading',
#  'godfather',
#  'secrets',
#  'Eve',
#  'Steampunk',
#  'laconic',
#  'Oakland',
#  'elegiac',
#  'Triad',
#  'women',
#  'alsace',
#  'LIVIN',
#  'Chocolat',
#  'iceburg',
#  'bold',
#  'salvation',
#  'Transitions',
#  'espers',
#  'bane',
#  'wizards',
#  'segments',
#  'gardening',
#  'Aaliyah',
#  'interwar',
#  'cliches',
#  'somber',
#  'dsfd',
#  'catacombs',
#  'ugly',
#  'medicien',
#  'existence',
#  'seance',
#  'usa',
#  'geeks',
#  'talky',
#  'Sinatra',
#  'Musicians',
#  'Rintaro',
#  'animals',
#  'Zurich',
#  'extraneous',
#  'Smoking',
#  'bio',
#  'mediacentralism',
#  'frustration',
#  'moldy',
#  'rangers',
#  'gamble',
#  'bright',
#  'lying',
#  'Catwoman',
#  'training',
#  'ransom',
#  'CinemaScope',
#  'modernism',
#  'Tromaesque',
#  'mosfilm',
#  'overblessed',
#  'enigmas',
#  'fistfighting',
#  'Fidel',
#  'family',
#  'palestine',
#  'independence',
#  'barbecue',
#  'setting',
#  'Witty',
#  'exploitive',
#  'tranquilizers',
#  'Night',
#  'crimen',
#  'massacre',
#  'Futbol',
#  'bill',
#  'bootytastic',
#  'd',
#  'soilders',
#  'CLV',
#  'quiet',
#  'weightlessness',
#  'vanxo',
#  'Creepy',
#  'Mexican',
#  'kaiju',
#  'fetish',
#  'Spoof',
#  'comeback',
#  'peace',
#  'suffering',
#  'Havana',
#  'frivilous',
#  'divertente',
#  'expatriate',
#  'gps',
#  'brainwashing',
#  'intimate',
#  'Garth',
#  'Turkmenistan',
#  'porn',
#  'swindle',
#  'mockbuster',
#  'purile',
#  'polemic',
#  'innocence',
#  'tripe',
#  'brutal',
#  'disacknowledged',
#  'privatization',
#  'Debate',
#  'offbeat',
#  'chickflick',
#  'digital',
#  'mvlc',
#  'carpet',
#  'M',
#  'Rome',
#  'Texan',
#  'interrogation',
#  'Poverty',
#  'Colors',
#  'moores',
#  'tv',
#  'bollox',
#  'denial',
#  'friend',
#  'hair',
#  'rooftop',
#  'foul',
#  'Phantom',
#  'biking',
#  'Intrigue',
#  'gothic',
#  'beauty',
#  'supercalifragilisticexpialidocious',
#  'WTF',
#  'Monte',
#  'wall',
#  'obejrzane',
#  'Sarcastic',
#  'mannequin',
#  'contemplative',
#  'Costumes',
#  'vapid',
#  'psychic',
#  'Gettysburge',
#  'taliban',
#  'DVD1',
#  'Ropes',
#  'prison',
#  'Surrealism',
#  'lightsabers',
#  'ecological',
#  'biology',
#  'bobsled',
#  'Absurd',
#  'Honor',
#  'Realist',
#  'Narnia',
#  'misinformation',
#  'ship',
#  'malicious',
#  'wincest',
#  'womanizing',
#  'hehehe',
#  'pseduscience',
#  'VOODOO',
#  'retirees',
#  'histroy',
#  'HD',
#  'Deutschland',
#  'aviation',
#  'siddig',
#  'homerus',
#  'fear',
#  'religous',
#  'obstinance',
#  'Undertaker',
#  'militarism',
#  'apathy',
#  'Asterix',
#  'Hanoi',
#  'matemathic',
#  'anticlimactic',
#  'gore',
#  'train',
#  'italians',
#  'pilots',
#  'transhumanist',
#  'Action',
#  'Eerie',
#  'philosophical',
#  'Horses',
#  'posession',
#  'bigfoot',
#  'destruction',
#  'UFOs',
#  'dj',
#  'assassin',
#  'afi',
#  'wars',
#  'PBS',
#  'colombia',
#  'Groupies',
#  'Austin',
#  'Dublin',
#  'widowhood',
#  'awkward',
#  'bitt',
#  'manipulative',
#  'Dracula',
#  'net',
#  'mars',
#  'UK',
#  'buscemi',
#  'SNL',
#  'netflix',
#  'amateurish',
#  'dildo',
#  'Whedon',
#  'CIA',
#  'foriegn',
#  'epiphany',
#  'unsuspenseful',
#  'super',
#  'activism',
#  'cuentos',
#  'locusts',
#  'gurgle',
#  'DADT',
#  'STUPID',
#  'Colonial',
#  'harpoon',
#  'true',
#  'righteous',
#  'uninspiring',
#  'narcissism',
#  'conte',
#  'spirituality',
#  'maths',
#  'miami',
#  'Clean',
#  'Pretentious',
#  '70mm',
#  'cube',
#  'choral',
#  'rendition',
#  'Fundamentalism',
#  'Zilla',
#  'Anonymous',
#  'ytmnd',
#  'Cyprus',
#  'easy',
#  'holographics',
#  'birth',
#  'thugs',
#  'futurama',
#  'recovery',
#  'swearing',
#  'entrepreneur',
#  'irrepressible',
#  'Campy',
#  'wrath',
#  'paycheck',
#  'Gambling',
#  'Disney',
#  'Matriculated',
#  'talk',
#  'Heartwarming',
#  'arnold',
#  'based',
#  'memories',
#  'Popcorn',
#  'lovely',
#  'Priority',
#  'Deep',
#  'infant',
#  'artistic',
#  'Mexico',
#  'immoral',
#  'intrigues',
#  'dad',
#  'dramalama',
#  'look',
#  'mathematician',
#  'nanny',
#  'henson',
#  'opression',
#  'blunderbuss',
#  'Toronto',
#  'blind',
#  'Deutsch',
#  'Wilder',
#  'oz',
#  'pancakes',
#  'dictadura',
#  'madcap',
#  'loneliness',
#  'wealth',
#  'social',
#  'Oslo',
#  'horse',
#  'presumptuousness',
#  'wheelchair',
#  'maturity',
#  'title',
#  'Lithuania',
#  'Amaguana',
#  'bouncer',
#  'doping',
#  'Anou',
#  'Reuters',
#  'bar',
#  'lataappa',
#  'DNA',
#  'mess',
#  'autobiographical',
#  'battle',
#  'eavesdropping',
#  'Highschool',
#  'söt',
#  'flubber',
#  'Yosemite',
#  'bondage',
#  'Manic',
#  'sightsound',
#  'narrow',
#  'suburbia',
#  'masculine',
#  'perfect',
#  'Maori',
#  'misadventures',
#  'interpretable',
#  'Venezuela',
#  'Zatoichi',
#  'rent',
#  'weed',
#  'crafted',
#  'Capote',
#  'mercy',
#  'FilmFour',
#  'SAS',
#  'moronic',
#  'penniless',
#  'relativism',
#  'Greenland',
#  'dentists',
#  'daemons',
#  'weihnachtsfilm',
#  'slick',
#  'zebra',
#  'nicolson',
#  'Tolkein',
#  'prauge',
#  'misleading',
#  'stapler',
#  'idiocy',
#  'Minilla',
#  'network',
#  'Starz',
#  'filming',
#  'masterful',
#  'Cartoon',
#  'sophisticated',
#  'baginski',
#  'pious',
#  'stunning',
#  'lacrosse',
#  'operetta',
#  'eerie',
#  'hulu',
#  'Tianjin',
#  'mentor',
#  'MLK',
#  'penpals',
#  'raunchy',
#  'gorno',
#  'loud',
#  'joyride',
#  'flashback',
#  'shark',
#  'underground',
#  'addictive',
#  'famer',
#  'pop',
#  'dark',
#  'sophomoric',
#  'Courtesans',
#  'hangover',
#  'transplants',
#  'hysteria',
#  'ulhas',
#  'ticket',
#  'Trial',
#  'Melbourne',
#  'Pondicherry',
#  'favorites',
#  'POWs',
#  'methamphetamines',
#  'ominous',
#  'colorado',
#  'archetypes',
#  'bands',
#  'Musicals',
#  'bullshit',
#  'Pompeii',
#  'ironc',
#  'Paranoia',
#  'Shooting',
#  'Oklahoma',
#  'test32',
#  'mafia',
#  'repetitious',
#  'Schoolgirls',
#  'Guatemala',
#  'louisiana',
#  'philosopical',
#  'Malaysia',
#  'previsible',
#  'Ending',
#  'Denmark',
#  '70s',
#  'Fearmongering',
#  'first',
#  'Scrooge',
#  'genius',
#  'budget',
#  'chopra',
#  'PTSD',
#  'Imprisonment',
#  'muder',
#  'insects',
#  'montreal',
#  'inspiring',
#  'Immigration',
#  'charmless',
#  'Dallas',
#  'ridiculus',
#  'slackers',
#  'bombs',
#  'melancholie',
#  'Claustrophobic',
#  'merde',
#  'inclusive',
#  'Premonition',
#  'Judy',
#  'Filmifriikki',
#  'hollow',
#  'Desghidorah',
#  'Calm',
#  'asians',
#  'trailblazing',
#  'lighting',
#  'Gays',
#  'seamless',
#  'heartbreak',
#  'unnecessary',
#  'ripley',
#  'WHO',
#  'mean',
#  'acting',
#  'underwhelming',
#  'mob',
#  'castle',
#  'engaging',
#  'speeding',
#  'womanhood',
#  'pittsburgh',
#  'Powhatan',
#  'Borg',
#  'styling',
#  'decadent',
#  'drew',
#  'Liberace',
#  'algeria',
#  'gangsters',
#  'ice',
#  'Xmas',
#  'jaws',
#  'childhood',
#  'Sicily',
#  'America',
#  'xenophobia',
#  'remake',
#  'biting',
#  'grace',
#  'feelgood',
#  'hyperbole',
#  'stress',
#  'biker',
#  'indians',
#  'outcast',
#  'cyborg',
#  'agents',
#  'sappy',
#  'fundamentalism',
#  'Smeat',
#  'banned',
#  'Alcatraz',
#  ...}

# %%
# !pip install transformers sentence-transformers
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.35.2)
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
# done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (2.0.0+cpu)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.15.1+cpu)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (3.2.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->sentence-transformers) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
# done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=391abbee4d66cecfca3dd1ebf1abba844a52063a49b670e6ee31f0c25b89012c
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.2.2

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np
import torch
from tqdm import tqdm

# %%
# define your word list
words_list=list(tag_set)
# Embed the entire corpus for semantic search
corpus = words_list
# Select model for semantic similarity search
model = SentenceTransformer('stsb-roberta-large')
# encode corpus to get corpus embeddings
corpus_embeddings = model.encode(corpus, convert_to_tensor=True)
# Out:
# .gitattributes:   0%|          | 0.00/748 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.92k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/287 [00:00<?, ?it/s]

# %%
def create_cluster(corpus, corpus_embeddings, threshold = 0.75):
    tag_to_clusterid = {}
    clusterid_to_tag = {}
    
#     # Embed the entire corpus for semantic search
#     corpus = words_list
#     # Select model for semantic similarity search
#     model = SentenceTransformer('stsb-roberta-large')
#     # encode corpus to get corpus embeddings
#     corpus_embeddings = model.encode(corpus, convert_to_tensor=True)
    
    # top_k results to return
    top_k=len(corpus)
    
    for index in tqdm(range(len(corpus))):
        ref_tag = corpus[index]
        id1 = index
        if ref_tag not in tag_to_clusterid:
            # New tag registered
            tag_to_clusterid[ref_tag] = id1
            clusterid_to_tag[id1] = set()
            clusterid_to_tag[id1].add(ref_tag) 
        else:
            # tag already present
            id1 = tag_to_clusterid[ref_tag]
            
        # iterate through each embedding as a reference
        sentence_embedding = corpus_embeddings[index]
        
        # compute similarity scores of the sentence with the corpus
        cos_scores = util.pytorch_cos_sim(sentence_embedding, corpus_embeddings)[0]
        # Sort the results in decreasing order and get the first top_k
        top_results = np.argpartition(-cos_scores, range(top_k))[0:top_k]
        for idx in top_results[0:top_k]:
            if cos_scores[idx] < threshold:
                break
            tag = corpus[idx]
            if tag not in tag_to_clusterid:
                # New tag registered
                tag_to_clusterid[tag] = id1
                clusterid_to_tag[id1].add(tag)
            else:
                id2 = tag_to_clusterid[tag]
                if id1 != id2:
                    # Combine the two groups with same tag but different ids
                    tags = clusterid_to_tag[id2]
                    for t in tags:
                        tag_to_clusterid[t] = id1
                        clusterid_to_tag[id1].add(t)
                    
                    del clusterid_to_tag[id2]
#                     print(tag_to_clusterid)
                    
#                     # tag already present in dictionary but cannot have two different ids
#                     raise Exception(f"There cannot be two different id {id1}, {id2} for {tag}")
                
    return tag_to_clusterid, clusterid_to_tag

# %%
tag_to_clusterid, clusterid_to_tag = create_cluster(corpus, corpus_embeddings, threshold = 0.8)
# Out:
# 100%|██████████| 9165/9165 [24:03<00:00,  6.35it/s]

# %%
clusterid_to_tag
# Out:
# {0: {'Favelas', 'favela', 'favelas'},
#  1: {'morbid'},
#  2: {'Chicago', 'chicago'},
#  3: {'Xerxes'},
#  4: {'wit'},
#  5: {'uncompromising'},
#  8: {'chipmunks'},
#  9: {'Isolation', 'isolation', 'isolationist', 'seclusion'},
#  10: {'storm'},
#  12: {'scooter'},
#  13: {'stirring'},
#  14: {'Water', 'water'},
#  15: {'bee'},
#  16: {'Atheism', 'atheism', 'atheist'},
#  17: {'Betrayal',
#   'Deception',
#   'Deceptive',
#   'Fake',
#   'Fraud',
#   'Heist',
#   'Illusionism',
#   'Misrepresented',
#   'Rape',
#   'Rapist',
#   'Robbery',
#   'Scam',
#   'Scams',
#   'Theft',
#   'bandit',
#   'bandits',
#   'betrayal',
#   'betrayl',
#   'counterfeiting',
#   'deception',
#   'deceptive',
#   'delusion',
#   'delusional',
#   'fake',
#   'farce',
#   'forgery',
#   'fraud',
#   'heist',
#   'hoax',
#   'illusion',
#   'illusionism',
#   'illusionist',
#   'illusions',
#   'looters',
#   'misbegotten',
#   'misguided',
#   'misinformation',
#   'misinterpretation',
#   'misleading',
#   'misrepresentation',
#   'misunderstanding',
#   'misunderstandings',
#   'misunderstood',
#   'rape',
#   'rapey',
#   'rapist',
#   'robbers',
#   'robbery',
#   'scam',
#   'scams',
#   'smug',
#   'stealing',
#   'steals',
#   'swindle',
#   'theft',
#   'thief',
#   'thieves',
#   'thuggery',
#   'thugs'},
#  18: {'AVORRIDA'},
#  19: {'cult'},
#  20: {'Mockumentary', 'mockumentary', 'mockumentry'},
#  21: {'whistleblower'},
#  22: {'dwarf', 'dwarfs'},
#  23: {'bird', 'birding', 'birds'},
#  24: {'Boring', 'boring'},
#  25: {'Gypsy', 'gypsy'},
#  26: {'Panama'},
#  27: {'cougars'},
#  28: {'Sociopath', 'sociopath', 'sociopathic', 'sociopaths'},
#  29: {'Karate', 'karate'},
#  30: {'gnosticism'},
#  31: {'Harlem', 'harlem'},
#  32: {'Chad', 'chad'},
#  33: {'DUI', 'dualism', 'duality', 'duel', 'duplicity', 'twins'},
#  34: {'Oedipus'},
#  35: {'Novelist', 'novel', 'novelist'},
#  36: {'Wittgenstein'},
#  37: {'wholesome'},
#  38: {'Hostages', 'hostage', 'hostages'},
#  39: {'anticommunists'},
#  40: {'Life', 'life'},
#  41: {'Catholic',
#   'Catholicism',
#   'Catholicvatican',
#   'cathartic',
#   'catholic',
#   'vatican'},
#  42: {'cineastic'},
#  43: {'Criticism', 'critic', 'criticism'},
#  44: {'Partisans', 'partisans', 'partisanship'},
#  46: {'Revamp'},
#  47: {'Stoner', 'stoner'},
#  48: {'perversion', 'perverted'},
#  49: {'zegist'},
#  50: {'hopeful', 'optimism', 'optimistic'},
#  52: {'tough'},
#  54: {'Resolution'},
#  56: {'Typical', 'typical'},
#  57: {'Red', 'Redux', 'red', 'redface', 'redhead', 'redneck'},
#  58: {'ocean'},
#  59: {'confession', 'confessional'},
#  60: {'Architecture', 'architecture'},
#  61: {'ignorance'},
#  62: {'Narration', 'narration'},
#  63: {'Growth', 'growth'},
#  64: {'Greenland', 'Greenwich', 'green'},
#  65: {'Convent', 'convent'},
#  66: {'MATCHMAKERS', 'Matchmaking', 'matchmaker', 'matchmaking'},
#  67: {'Rose'},
#  68: {'minnsota'},
#  69: {'jeff', 'jeffrey'},
#  70: {'drought'},
#  71: {'indoctrination'},
#  72: {'Words'},
#  73: {'grandstand'},
#  74: {'taboo'},
#  75: {'Grey', 'gray'},
#  76: {'trolls'},
#  77: {'Friendship', 'friend', 'friendnship', 'friends', 'friendship'},
#  78: {'Touching', 'touching'},
#  79: {'trick'},
#  80: {'Poverty', 'poor', 'poorness', 'poverty'},
#  81: {'Lyrical', 'lyrical'},
#  82: {'Norway', 'Norwegian', 'norway', 'norwegian'},
#  83: {'malaria'},
#  84: {'Gay', 'gay', 'gayish'},
#  85: {'carbonite'},
#  86: {'fantacy', 'fantasies'},
#  87: {'Samurai', 'samurai'},
#  88: {'Country', 'country'},
#  89: {'seeout'},
#  90: {'Fosse'},
#  91: {'sleaze'},
#  92: {'Torture', 'torture'},
#  94: {'silhouettes'},
#  96: {'THEATER',
#   'Theater',
#   'Theatre',
#   'theater',
#   'theatre',
#   'theatres',
#   'theatrical'},
#  97: {'Adrenaline', 'adrenaline'},
#  98: {'Hookers', 'hooker'},
#  99: {'Thor', 'thiller', 'thong', 'thug'},
#  100: {'orgy'},
#  101: {'Idaho', 'idaho'},
#  102: {'ETA'},
#  103: {'inicom'},
#  104: {'afi100'},
#  105: {'Clinton', 'clinton'},
#  106: {'Immigrant',
#   'Immigrants',
#   'immigrant',
#   'immigrants',
#   'migrants',
#   'migration'},
#  107: {'retro'},
#  108: {'Peron'},
#  109: {'Anthropomorphic',
#   'anthropology',
#   'anthropomorphic',
#   'anthropomorphism'},
#  110: {'canoeing'},
#  112: {'unfair'},
#  113: {'Fable', 'fable'},
#  114: {'Hockey', 'hockey'},
#  116: {'nonconformity'},
#  117: {'spelunking'},
#  118: {'unsafisfying'},
#  119: {'vulnerability'},
#  120: {'peasants'},
#  121: {'romanc'},
#  122: {'boheme'},
#  123: {'mutiny'},
#  124: {'synagogue'},
#  126: {'Marines', 'marines'},
#  128: {'clique', 'cliques'},
#  129: {'Padding', 'padding'},
#  130: {'dreary'},
#  131: {'ninja', 'ninjas'},
#  132: {'curling'},
#  133: {'innuendo', 'inuendo'},
#  134: {'woodstock'},
#  135: {'darfur'},
#  136: {'robo', 'robot', 'robotics'},
#  137: {'Werewolves',
#   'Wolves',
#   'werewolf',
#   'werewolves',
#   'wolf',
#   'wolfs',
#   'wolves'},
#  138: {'compilation'},
#  140: {'odysseus'},
#  141: {'victory', 'winning', 'winnings'},
#  142: {'intellegent'},
#  143: {'Mario', 'mario'},
#  144: {'punks'},
#  145: {'puka'},
#  147: {'Maya', 'maya', 'mayan'},
#  149: {'peeta'},
#  150: {'dani2008'},
#  152: {'Republic', 'Republicans'},
#  153: {'Marriage',
#   'Wedding',
#   'bride',
#   'bridegroom',
#   'couple',
#   'marriage',
#   'newlyweds',
#   'wedding',
#   'weddings'},
#  155: {'diner'},
#  156: {'Legal', 'legal'},
#  157: {'Target'},
#  158: {'Paradox', 'paradox', 'paradoxical'},
#  159: {'botany'},
#  160: {'madc'},
#  161: {'Rain', 'Rainstorm', 'rain', 'rainy'},
#  162: {'GLBT', 'glbt'},
#  163: {'arch'},
#  164: {'inimitable'},
#  165: {'DA', 'Daring', 'd', 'dare', 'daring', 'diddy'},
#  166: {'swimming'},
#  167: {'macross'},
#  168: {'sheep'},
#  169: {'Reenactment', 'reenactments'},
#  170: {'Screenplay', 'screenplay'},
#  171: {'promise'},
#  172: {'bailiff'},
#  173: {'existentialism', 'existentialist'},
#  174: {'bluegrass'},
#  175: {'Skeletor', 'skeletons', 'skeletor'},
#  176: {'Portuguese'},
#  177: {'Unfunny', 'unfunny'},
#  178: {'reconciliation', 'reconciling'},
#  180: {'Dreyer'},
#  181: {'India',
#   'Indian',
#   'Indiana',
#   'Indians',
#   'Indie',
#   'Indochina',
#   'india',
#   'indian',
#   'indiana',
#   'indians',
#   'indie',
#   'indy'},
#  182: {'Battles', 'battles'},
#  183: {'Nostalgia', 'nostalgia'},
#  184: {'steamboats'},
#  186: {'Mossad', 'mossad'},
#  187: {'unconvincing'},
#  188: {'Moon', 'moon'},
#  189: {'girl', 'girls'},
#  190: {'body'},
#  191: {'moneypenny'},
#  192: {'shoa'},
#  193: {'sassy'},
#  194: {'strategy'},
#  197: {'dingy'},
#  198: {'President', 'president'},
#  199: {'Individualism', 'individual', 'individualism'},
#  200: {'catapult'},
#  201: {'metafilm'},
#  202: {'gargoyles'},
#  203: {'snob'},
#  204: {'institutionalization', 'institutions'},
#  205: {'Uggie'},
#  206: {'Insanity', 'insanity'},
#  207: {'lulz'},
#  208: {'creationism'},
#  209: {'Hedonism', 'hedonist'},
#  210: {'solitude'},
#  211: {'imagine'},
#  212: {'ex'},
#  213: {'Lame', 'Lamer', 'lame'},
#  214: {'Satan', 'Satanism', 'satan', 'satanism'},
#  215: {'Spells'},
#  216: {'Fox', 'fox', 'foxes'},
#  217: {'avi'},
#  218: {'Altman'},
#  219: {'spirits'},
#  220: {'ABBA'},
#  221: {'Fischhorror', 'fischhorror'},
#  222: {'rund'},
#  223: {'vocabullary'},
#  224: {'party'},
#  225: {'tender'},
#  226: {'Sleep', 'Sleeper', 'sleep', 'sleeper', 'sleepy'},
#  227: {'fisting'},
#  229: {'powers'},
#  230: {'SEAL', 'seals'},
#  231: {'kamikaze'},
#  232: {'psycodelic'},
#  233: {'hooligans'},
#  234: {'speakeasy'},
#  235: {'nuda'},
#  236: {'Affair', 'Affairs', 'affair'},
#  237: {'jilted'},
#  238: {'exploration'},
#  239: {'surrogacy', 'surrogate'},
#  240: {'Gratuitous', 'gratuitous'},
#  241: {'zoo'},
#  243: {'Barbarian'},
#  244: {'impressionistic', 'impressions', 'impressive'},
#  246: {'BEAUTIFUL', 'Beautiful', 'beautiful', 'beautifull'},
#  247: {'trust'},
#  248: {'opossums'},
#  249: {'moped'},
#  250: {'Ital'},
#  251: {'Crossdressing', 'crossdressing'},
#  252: {'lovecraft', 'lovecraftian'},
#  253: {'Dull', 'dull'},
#  254: {'Zimbabwe', 'zimbabwe'},
#  255: {'pacifist', 'pacifistas'},
#  256: {'Straightforward', 'straightforward'},
#  257: {'kuenstlerroman'},
#  258: {'patient'},
#  259: {'multilayered'},
#  260: {'neorealism'},
#  261: {'marine', 'submarine', 'submarines'},
#  265: {'multifaceted'},
#  267: {'finance'},
#  268: {'Galactica', 'galactic'},
#  269: {'ronin'},
#  270: {'melee'},
#  271: {'complot'},
#  272: {'ring', 'rings'},
#  273: {'skinhead', 'skinheads'},
#  274: {'collectible', 'collector'},
#  275: {'Witty', 'witty'},
#  276: {'Plastics'},
#  277: {'mixtape'},
#  278: {'Owls', 'owls'},
#  279: {'Italian', 'Italy', 'italian', 'italians', 'italy'},
#  280: {'Amtrak'},
#  281: {'Wolverine', 'wolverine'},
#  282: {'Fictional', 'fictional'},
#  284: {'Alaska', 'alaska'},
#  285: {'Ukraine', 'ukraine'},
#  287: {'subordination'},
#  288: {'Faries'},
#  289: {'mkv'},
#  290: {'Guilt', 'guilt', 'guilty'},
#  292: {'Gilliam'},
#  293: {'Antichrist', 'antichrist', 'antichristian'},
#  295: {'Schizophrenia', 'Schizophrenic', 'schizophrenia'},
#  296: {'refugee', 'refugees'},
#  297: {'unwatchable'},
#  298: {'gentle'},
#  300: {'unscary'},
#  301: {'ACTION', 'Acting', 'Action', 'acting', 'action'},
#  302: {'presentation'},
#  304: {'pyschology', 'pyschopath'},
#  305: {'Portugal'},
#  306: {'Siegfried'},
#  307: {'Queen', 'queen', 'queer'},
#  308: {'autumnal'},
#  309: {'BSDM'},
#  310: {'rumor'},
#  311: {'Russia', 'Russian', 'Russians', 'russia', 'russian', 'russians'},
#  312: {'dutch'},
#  314: {'Assassins', 'assasination', 'assassination', 'assassins'},
#  315: {'awareness', 'consciousness'},
#  316: {'insularity'},
#  317: {'Mediocre', 'mediocre'},
#  318: {'Drag', 'drag', 'dragged', 'draggy', 'drags'},
#  319: {'harmonica'},
#  320: {'blacklist', 'blacklisting'},
#  321: {'Pulp', 'pulp'},
#  322: {'Competition', 'competition', 'contest'},
#  323: {'toplist10'},
#  324: {'Screwball', 'screwball'},
#  325: {'ldschoolcool'},
#  326: {'realtime'},
#  327: {'montage', 'montages'},
#  328: {'Tragedy', 'Tragic', 'tragedy', 'tragic', 'tragicomic'},
#  329: {'strangulation'},
#  330: {'Geese', 'geese'},
#  331: {'Baghdad'},
#  332: {'cards'},
#  333: {'Rave', 'rave'},
#  334: {'Stylish', 'stylish'},
#  335: {'apprenticeship'},
#  336: {'Homeless', 'Homelessness', 'homeless', 'homelessness'},
#  337: {'Hulk', 'hulk'},
#  338: {'moth'},
#  339: {'Cast', 'Casting', 'cast', 'casting', 'castration'},
#  340: {'insubordination'},
#  341: {'inappropriate'},
#  342: {'skinnydipping'},
#  343: {'Melancholic', 'melancholic', 'melancholy'},
#  344: {'stamps'},
#  345: {'sdf', 'sdfsdfsdfsdfsdfsdf'},
#  346: {'KAF', 'kafkaesque'},
#  349: {'Circus', 'circus'},
#  350: {'Yakuza', 'yakuza'},
#  351: {'entrepreneur', 'entrepreneurs'},
#  352: {'Katottava'},
#  353: {'orgiginal', 'orginal'},
#  354: {'fire', 'fireworks'},
#  355: {'Florence', 'Florida', 'florence', 'florida'},
#  356: {'auteur'},
#  357: {'Hirohito', 'Hiroshima'},
#  358: {'automata'},
#  359: {'ruthless'},
#  360: {'TOSTON'},
#  361: {'climate'},
#  362: {'KIDNAPPING', 'Kidnapping', 'kidnap', 'kidnapping'},
#  363: {'data'},
#  364: {'Cynism', 'cynical'},
#  365: {'Maserati'},
#  366: {'NATO'},
#  367: {'Caribbean'},
#  368: {'Maffia'},
#  370: {'Gag', 'gags'},
#  372: {'estrangeinro'},
#  373: {'Pornographic', 'porn', 'pornalicious', 'pornography', 'pornstars'},
#  374: {'Exciting',
#   'Inspiration',
#   'Inspirational',
#   'Inspiring',
#   'exciting',
#   'inspiration',
#   'inspirational',
#   'inspiring',
#   'invigorating'},
#  375: {'millionare'},
#  376: {'prequel'},
#  377: {'kickboxing'},
#  380: {'London', 'london'},
#  381: {'homophobia', 'homophobic'},
#  382: {'grainy'},
#  383: {'Europe', 'European', 'europa', 'europe', 'european'},
#  384: {'unfulfilling'},
#  385: {'medschool'},
#  386: {'caravan'},
#  387: {'Program'},
#  388: {'Unremarkable', 'unremarkable'},
#  389: {'travel', 'traveling', 'travelling'},
#  390: {'G', 'GM', 'Gigi', 'Grail', 'gale', 'gps'},
#  391: {'play', 'playful'},
#  392: {'COLONIALISM', 'Colonial', 'Colonialism', 'colonial', 'colonialism'},
#  393: {'Grindhouse', 'grindhouse'},
#  394: {'frontier'},
#  395: {'narf'},
#  396: {'Freedom', 'freedom'},
#  397: {'Weihnachtsfilm', 'weihnachtsfilm'},
#  398: {'moonshine'},
#  399: {'sterility'},
#  400: {'mentiras', 'mentiroso'},
#  401: {'zeppelin'},
#  404: {'bioterrorism'},
#  405: {'bright', 'shiny'},
#  406: {'katana'},
#  407: {'Antihero', 'antihero'},
#  408: {'hearthwarming'},
#  409: {'Wales', 'Welsh', 'wales', 'welsh'},
#  410: {'Cheese', 'Cheesy', 'cheese', 'cheesey', 'cheesiness', 'cheesy'},
#  412: {'Rihanna'},
#  413: {'elite', 'elitism'},
#  414: {'company'},
#  415: {'Lobbyism', 'Lobbyist', 'lobbyism'},
#  416: {'Playlist'},
#  417: {'moose'},
#  418: {'Linkoping'},
#  419: {'hashish'},
#  420: {'Texan', 'Texas', 'texas'},
#  421: {'uranium'},
#  422: {'Stargate', 'stargate'},
#  423: {'cringe'},
#  424: {'onirism'},
#  425: {'captivity'},
#  427: {'transvestite', 'transvestites'},
#  428: {'inside'},
#  429: {'Nirvana', 'nirvana'},
#  430: {'Bullshit', 'bullshit', 'bullshitting'},
#  431: {'Emperor', 'emperor'},
#  432: {'FORM'},
#  433: {'existensial', 'existensialism'},
#  434: {'Isis'},
#  435: {'EPIC', 'Epic', 'epic'},
#  436: {'storry'},
#  437: {'Domination', 'dominance', 'domination'},
#  438: {'lonliness'},
#  440: {'reflection', 'reflective'},
#  441: {'Batman', 'batman'},
#  442: {'Pointless', 'pointless'},
#  443: {'Cheating', 'cheating', 'cheats'},
#  444: {'Goemon'},
#  445: {'Landscapes', 'landscape', 'landscapes'},
#  446: {'rickyism'},
#  447: {'aztec'},
#  448: {'delicious'},
#  449: {'retarted'},
#  450: {'Hobbits', 'hobbit', 'hobbits'},
#  451: {'authentic', 'authenticity'},
#  453: {'Barcelona'},
#  454: {'understated'},
#  455: {'Ending',
#   'Retirement',
#   'Terminator',
#   'decapitation',
#   'demise',
#   'ending',
#   'endings',
#   'finale',
#   'graduation',
#   'retirees',
#   'retirement',
#   'terminator'},
#  456: {'Unsettling', 'unsettling'},
#  457: {'Tierhorror', 'tierhorror'},
#  458: {'Biopic', 'biopic'},
#  459: {'dusty'},
#  460: {'steamy'},
#  461: {'Masons'},
#  462: {'surgeon', 'surgery'},
#  463: {'Literary',
#   'Literature',
#   'literacy',
#   'literary',
#   'literate',
#   'literature'},
#  464: {'Finland',
#   'Finlandia',
#   'Finnish',
#   'Finns',
#   'finland',
#   'finnish',
#   'finnland'},
#  465: {'sociolagy'},
#  466: {'Thrilling', 'enthralling', 'thriler', 'thrilling'},
#  467: {'masks'},
#  468: {'Mamet', 'mamet'},
#  469: {'sentiment', 'sentimental', 'sentimentality'},
#  470: {'malik'},
#  471: {'Rameshwaram'},
#  472: {'recycling'},
#  474: {'dormitory'},
#  475: {'Adventure', 'adventure', 'adventureous', 'adventurous', 'venture'},
#  476: {'Lottery', 'lottery'},
#  477: {'elves'},
#  478: {'CREATIVE', 'Creative', 'creative', 'creativity'},
#  479: {'traumatic'},
#  480: {'Memphis'},
#  482: {'expedition'},
#  483: {'raccoon'},
#  484: {'Intense', 'dense', 'intense'},
#  485: {'spiral'},
#  486: {'Gun',
#   'Guns',
#   'Shooting',
#   'Shotgun',
#   'firearms',
#   'gun',
#   'gunfight',
#   'gunfights',
#   'guns',
#   'shooter',
#   'shooting',
#   'shootout',
#   'shotgun',
#   'weapons',
#   'weaponsmith'},
#  487: {'nonsensical'},
#  488: {'marathons'},
#  489: {'Incest', 'incest'},
#  490: {'Trieste'},
#  491: {'boomerang'},
#  493: {'Twist', 'Twists', 'twist', 'twisted', 'twists', 'twisty'},
#  494: {'margaritas'},
#  495: {'Atreyu'},
#  496: {'Diary', 'diary'},
#  497: {'raunch', 'raunchy'},
#  498: {'Advertising', 'advertising', 'commercial'},
#  499: {'Apatow'},
#  500: {'holes90s'},
#  501: {'Antisemitism', 'antisemitism'},
#  502: {'degradation', 'degrading'},
#  503: {'godfather'},
#  504: {'secrecy', 'secret', 'secrets'},
#  505: {'Eve'},
#  506: {'Steampunk', 'steampunk'},
#  507: {'laconic'},
#  508: {'Oakland'},
#  509: {'elegiac'},
#  510: {'Triad'},
#  511: {'Womanhood', 'woman', 'womanhood', 'women'},
#  512: {'alsace'},
#  513: {'LIVIN'},
#  515: {'iceburg'},
#  516: {'bold'},
#  517: {'Salvation', 'salvation'},
#  519: {'espers'},
#  520: {'Bane', 'bane'},
#  521: {'Wizards', 'wizard', 'wizards'},
#  522: {'segments'},
#  523: {'gardener', 'gardening'},
#  524: {'Aaliyah'},
#  525: {'interwar'},
#  526: {'Cliched', 'Cliches', 'cliched', 'cliches'},
#  527: {'somber'},
#  528: {'dsfd'},
#  529: {'catacombs'},
#  530: {'Ugly', 'ugly'},
#  531: {'Medicine', 'medical', 'medicien', 'medicine'},
#  532: {'existence'},
#  533: {'seance'},
#  534: {'USA', 'usa'},
#  535: {'Geeks', 'Geeky', 'geek', 'geeks', 'geeky'},
#  536: {'Dialogs',
#   'Dialogue',
#   'conversation',
#   'conversations',
#   'conversative',
#   'dialog',
#   'dialogs',
#   'dialogue',
#   'dialogues',
#   'interrogation',
#   'interview',
#   'interviews',
#   'talk',
#   'talkative',
#   'talky'},
#  537: {'Sinatra'},
#  539: {'Rintaro'},
#  540: {'Animal', 'Animals', 'animal', 'animals'},
#  541: {'Zurich'},
#  542: {'extraneous'},
#  543: {'Smoking', 'smoke', 'smoking'},
#  544: {'bio'},
#  545: {'mediacentralism'},
#  547: {'moldy'},
#  548: {'rangers'},
#  549: {'Gamble', 'gamble', 'gamification'},
#  551: {'Lies', 'liars', 'lie', 'lies', 'lying'},
#  552: {'Catwoman', 'catwoman'},
#  553: {'Training', 'training'},
#  554: {'ransom'},
#  556: {'modern', 'modernisation', 'modernism', 'modernity'},
#  557: {'Troma', 'Tromaesque', 'troma'},
#  558: {'Mosfilm', 'mosfilm'},
#  559: {'overblessed'},
#  560: {'enigmas'},
#  561: {'fistfighting'},
#  562: {'Fidel'},
#  563: {'Family', 'families', 'family', 'parenting', 'parents'},
#  564: {'Palestine', 'palestine'},
#  565: {'Independence', 'independence', 'independent'},
#  566: {'barbecue'},
#  569: {'exploitation', 'exploitative', 'exploitive'},
#  570: {'tranquilizers'},
#  572: {'Crime',
#   'GANGSTA',
#   'Gang',
#   'Gangland',
#   'Gangs',
#   'Gangster',
#   'MAFIA',
#   'Mafia',
#   'Mob',
#   'crime',
#   'crimen',
#   'criminal',
#   'criminals',
#   'gang',
#   'gangrape',
#   'gangs',
#   'gangster',
#   'gangsterfilm',
#   'gangsters',
#   'mafia',
#   'mob',
#   'mobster',
#   'mobsters'},
#  574: {'Futbol'},
#  575: {'bill'},
#  576: {'Bootytastic', 'bootytastic'},
#  578: {'soilders'},
#  579: {'CLV'},
#  580: {'Silence', 'Silent', 'quiet', 'silence', 'silent'},
#  581: {'weightlessness'},
#  582: {'vanxo'},
#  583: {'CREEPY', 'Creepy', 'creepy', 'spooky'},
#  584: {'Mexican', 'Mexico', 'mexians', 'mexican', 'mexico'},
#  585: {'Kaiju', 'kaiju'},
#  586: {'Fetish', 'fetish'},
#  587: {'Spoof', 'spoof'},
#  588: {'comeback'},
#  590: {'suffering'},
#  591: {'Havana'},
#  592: {'frivilous', 'frivolous'},
#  593: {'divertente'},
#  594: {'expatriate'},
#  596: {'brainwash', 'brainwashing'},
#  597: {'intimate'},
#  598: {'Garth'},
#  599: {'Turkmenistan'},
#  602: {'mockbuster'},
#  603: {'purile', 'puritan'},
#  604: {'polemic'},
#  605: {'innocence'},
#  606: {'Triads', 'Trilogy', 'Triplets', 'trilogy', 'trinity', 'tripe'},
#  608: {'disacknowledged'},
#  609: {'privatization'},
#  610: {'Debate', 'debate'},
#  611: {'Offbeat', 'offbeat'},
#  612: {'chickflick'},
#  613: {'digital'},
#  614: {'mvlc'},
#  615: {'carpet'},
#  616: {'M', 'ms'},
#  617: {'Roma', 'Rome', 'rome'},
#  622: {'moore', 'moores'},
#  623: {'TV', 'television', 'tv'},
#  624: {'bollox'},
#  625: {'denial'},
#  627: {'hair'},
#  628: {'rooftop'},
#  629: {'foul'},
#  630: {'Phantom'},
#  632: {'Intrigue',
#   'Intriguing',
#   'fascinating',
#   'intrigante',
#   'intrigue',
#   'intrigues',
#   'intriguing',
#   'intruiging'},
#  633: {'GOTHIC', 'Goth', 'Gothic', 'goth', 'gothic'},
#  634: {'Beauty', 'beauty'},
#  635: {'supercalifragilisticexpialidocious'},
#  636: {'WTF', 'wtf'},
#  637: {'Monte'},
#  638: {'Wall', 'wall'},
#  639: {'Obejrzane', 'obejrzane'},
#  640: {'Sarcastic'},
#  641: {'mannequin'},
#  642: {'contemplative'},
#  643: {'Costume', 'Costumes', 'costume', 'costumes'},
#  644: {'vapid'},
#  646: {'Gettysburge'},
#  647: {'Taliban', 'taliban'},
#  648: {'DVD1'},
#  649: {'Ropes'},
#  652: {'lightsabers'},
#  653: {'ecological', 'ecology'},
#  654: {'biology'},
#  655: {'bobsled'},
#  657: {'Honor', 'honesty', 'honor'},
#  658: {'Realism',
#   'Realist',
#   'Realistic',
#   'factual',
#   'real',
#   'realidad',
#   'realism',
#   'realist',
#   'realistic',
#   'realness',
#   'veracity'},
#  659: {'Narnia', 'narnia'},
#  661: {'ship', 'ships'},
#  662: {'malicious'},
#  663: {'wincest'},
#  664: {'womanizing'},
#  665: {'HEH', 'hehehe'},
#  666: {'pseduscience', 'psudoscience'},
#  667: {'VOODOO', 'Voodoo', 'voodoo'},
#  669: {'histroy'},
#  670: {'HD', 'hd', 'hdtv'},
#  671: {'Deutsch', 'Deutschland', 'deutsch'},
#  672: {'Aviation', 'aviation'},
#  673: {'siddig'},
#  674: {'Homer', 'homeros', 'homerus'},
#  676: {'religous'},
#  677: {'obstinance'},
#  678: {'Undertaker'},
#  679: {'militarism', 'militaristic'},
#  680: {'apathy'},
#  681: {'Asterix'},
#  682: {'Hanoi'},
#  683: {'matemathic'},
#  684: {'anticlimactic'},
#  685: {'Gore', 'gore'},
#  686: {'Train', 'train', 'trains'},
#  688: {'pilots'},
#  689: {'transhumanism', 'transhumanist'},
#  691: {'Eerie', 'Haunting', 'eerie', 'haunting'},
#  693: {'Horses', 'horse', 'horses'},
#  694: {'posession'},
#  695: {'bigfoot'},
#  696: {'destruction'},
#  697: {'UFO', 'UFOS', 'UFOs', 'ufo', 'ufos'},
#  698: {'dj'},
#  699: {'Assassin', 'assassin'},
#  700: {'afi'},
#  701: {'wars'},
#  702: {'PBS'},
#  703: {'Colombia', 'Colombian', 'colombia'},
#  704: {'Groupies', 'groupie', 'groupies'},
#  705: {'Austen',
#   'Austin',
#   'Australia',
#   'Australian',
#   'Austria',
#   'austere',
#   'australia',
#   'australian',
#   'austria',
#   'austrian'},
#  706: {'Dublin', 'dublin'},
#  707: {'Widow', 'Widower', 'widow', 'widower', 'widowhood'},
#  708: {'Awkward', 'awkward'},
#  709: {'bitt'},
#  710: {'manipulation', 'manipulative'},
#  711: {'Dracula', 'dracula'},
#  712: {'net'},
#  713: {'Mars', 'mars'},
#  714: {'UK', 'uk'},
#  715: {'buscemi'},
#  716: {'SNL', 'snl'},
#  717: {'Netflix', 'netflix', 'netflixq'},
#  718: {'Amateurish', 'amateur', 'amateurish'},
#  719: {'dildo'},
#  720: {'Whedon'},
#  721: {'CIA', 'cia'},
#  722: {'foriegn'},
#  723: {'epiphany'},
#  724: {'unsuspenseful'},
#  725: {'super'},
#  726: {'activism', 'activist'},
#  727: {'cuentos'},
#  728: {'locusts'},
#  729: {'gurgle'},
#  730: {'DADT'},
#  731: {'STUPID', 'Stupid', 'stupid', 'stupidity'},
#  733: {'harpoon'},
#  735: {'righteous'},
#  736: {'uninspired', 'uninspiring', 'uninteresting'},
#  737: {'Narcissistic', 'narcissism', 'narcissistic'},
#  738: {'conte'},
#  739: {'Spiritual', 'spiritual', 'spirituality'},
#  741: {'Miami', 'miami'},
#  742: {'Clean', 'clean'},
#  743: {'Pretentious',
#   'pretending',
#   'pretention',
#   'pretentious',
#   'pretentiousness'},
#  744: {'1970s', '70mm', '70s'},
#  745: {'cube'},
#  746: {'choral'},
#  747: {'rendition'},
#  748: {'Fundamentalism', 'fundamentalism'},
#  749: {'Zilla'},
#  750: {'Anonymous', 'anonymity'},
#  751: {'ytmnd'},
#  752: {'Cyprus'},
#  753: {'Simple', 'easy', 'easygoing', 'simple'},
#  754: {'hologram', 'holographics'},
#  757: {'futurama'},
#  758: {'recovery'},
#  759: {'Swearing', 'swearing'},
#  761: {'irrepressible'},
#  762: {'Camp', 'Campy', 'camp', 'camping', 'campy'},
#  764: {'paycheck'},
#  765: {'Gambling', 'gambling'},
#  766: {'Disney', 'Disneyworld', 'disney'},
#  767: {'Matriculated'},
#  769: {'Heartwarming', 'heartwarming'},
#  770: {'Arnold', 'arnold'},
#  771: {'based'},
#  773: {'Popcorn', 'popcorn'},
#  776: {'Deep', 'deep', 'depth'},
#  778: {'Art',
#   'Artist',
#   'Artistic',
#   'art',
#   'artist',
#   'artistic',
#   'artists',
#   'artwork'},
#  780: {'Immoral', 'immoral'},
#  782: {'Dad', 'dad', 'father', 'fatherhood'},
#  783: {'dramalama'},
#  784: {'look'},
#  785: {'Mathematics',
#   'math',
#   'mathematician',
#   'mathematicians',
#   'mathematics',
#   'maths'},
#  786: {'nanny'},
#  787: {'henson'},
#  788: {'opression'},
#  789: {'blunderbuss'},
#  790: {'Toronto', 'toronto'},
#  791: {'Blindfold', 'Blindness', 'blind', 'blindfold', 'blindness'},
#  793: {'Wilder'},
#  794: {'Oz', 'Ozarks', 'oz', 'ozarks', 'ozu', 'ozuka'},
#  795: {'pancakes'},
#  796: {'dictadura'},
#  797: {'madcap'},
#  798: {'Loneliness', 'loneliness'},
#  800: {'social'},
#  801: {'Oslo'},
#  803: {'presumptuousness'},
#  804: {'wheelchair'},
#  805: {'amature', 'mature', 'maturity'},
#  806: {'title'},
#  807: {'Lithuania'},
#  808: {'Amaguana'},
#  809: {'bouncer'},
#  810: {'doping'},
#  811: {'Anou'},
#  812: {'Reuters'},
#  813: {'BAr', 'bar'},
#  814: {'lataappa'},
#  815: {'DNA'},
#  816: {'Messy', 'mess', 'messy'},
#  817: {'autobiographical', 'autobiography'},
#  819: {'eavesdropping'},
#  820: {'Highschool', 'highschool'},
#  821: {'söt'},
#  822: {'flubber'},
#  823: {'Yosemite'},
#  824: {'Bond', 'Bondage', 'bond', 'bondage'},
#  825: {'Manic'},
#  826: {'sightsound'},
#  827: {'narrow'},
#  828: {'Suburbs', 'suburbia'},
#  829: {'Masculinity', 'masculine', 'masculinity'},
#  830: {'Perfect', 'perfect', 'perfection', 'perfectionism', 'perfectionist'},
#  831: {'Maori', 'maori'},
#  832: {'misadventures'},
#  833: {'interpretable'},
#  834: {'Venezuela'},
#  835: {'Zatoichi'},
#  836: {'RENT', 'rent', 'rented'},
#  837: {'weed'},
#  838: {'crafted'},
#  839: {'Capote'},
#  840: {'mercy'},
#  841: {'4', '4d', 'FilmFour'},
#  842: {'SAS'},
#  843: {'moronic'},
#  844: {'penniless'},
#  845: {'relativism'},
#  847: {'dentist', 'dentists'},
#  848: {'daemons'},
#  850: {'Slick', 'slick'},
#  851: {'zebra'},
#  852: {'nicolson'},
#  853: {'Tolkein'},
#  854: {'prauge'},
#  856: {'stapler'},
#  857: {'idiocy'},
#  858: {'Minilla'},
#  859: {'network'},
#  860: {'Starz'},
#  861: {'CinemaScope',
#   'Cinematography',
#   'Cinemotography',
#   'Cinemtography',
#   'FILMMAKING',
#   'Filmation',
#   'cinema',
#   'cinemascope',
#   'cinematic',
#   'cinematograp',
#   'cinematography',
#   'cinematrophy',
#   'film',
#   'filming',
#   'filmmakers',
#   'filmmaking',
#   'filmography',
#   'movie',
#   'movies'},
#  862: {'Masterpiece', 'masterful', 'mastermind', 'masterpiece'},
#  863: {'Cartoon', 'Cartoons', 'cartoon', 'cartoonish'},
#  864: {'sophisticated'},
#  865: {'baginski'},
#  866: {'pious'},
#  867: {'stunning'},
#  868: {'lacrosse'},
#  869: {'operetta', 'opretta'},
#  871: {'Hulu', 'hulu'},
#  872: {'Tianjin'},
#  873: {'Mentor', 'Mentorship', 'mentor'},
#  874: {'MLK'},
#  875: {'penpals'},
#  877: {'gorno'},
#  878: {'Loud', 'loud'},
#  879: {'joyride'},
#  880: {'Flashbacks', 'flashback', 'flashbacks'},
#  881: {'Shark', 'shark', 'sharks'},
#  883: {'Addiction', 'addiction', 'addictive'},
#  884: {'famer'},
#  885: {'pop'},
#  887: {'Sophomoric', 'sophomoric'},
#  888: {'Courtesans', 'courtesan'},
#  889: {'Hangover', 'hangover'},
#  890: {'transplants'},
#  891: {'Hysterical', 'hysteria', 'hysteric', 'hysterical'},
#  892: {'ulhas'},
#  893: {'ticket'},
#  894: {'Trial', 'trial'},
#  895: {'Melbourne'},
#  896: {'Pondicherry'},
#  897: {'Favorite', 'Favorites', 'favorite', 'favorites', 'favourite'},
#  898: {'POW', 'POWs', 'pows'},
#  899: {'methamphetamines'},
#  900: {'ominous'},
#  901: {'Colorado', 'colorado'},
#  902: {'archetypes'},
#  903: {'band', 'bands'},
#  906: {'Pompeii'},
#  907: {'ironc'},
#  908: {'Paranoia', 'paranoia'},
#  910: {'Oklahoma', 'oklahoma'},
#  911: {'test32'},
#  913: {'Repetitive', 'repeating', 'repetition', 'repetitious', 'repetitive'},
#  914: {'School', 'Schoolgirl', 'Schoolgirls', 'school', 'schools'},
#  915: {'Guatemala'},
#  916: {'Louisiana', 'louisiana'},
#  917: {'Philosophical',
#   'Philosophy',
#   'philosophical',
#   'philosophy',
#   'philosophycal',
#   'philosopical'},
#  918: {'Malaysia'},
#  919: {'invisible', 'previsible'},
#  921: {'Denmark', 'denmark'},
#  925: {'Scrooge'},
#  926: {'Genius', 'genius'},
#  927: {'budget'},
#  928: {'chopra'},
#  929: {'PTSD'},
#  930: {'Imprisonment',
#   'Prison',
#   'imprisonment',
#   'inmate',
#   'prison',
#   'prisoner',
#   'prisoners'},
#  931: {'muder'},
#  932: {'insects'},
#  933: {'Montreal', 'montreal'},
#  935: {'Immigration', 'immigration'},
#  936: {'charmless'},
#  937: {'Dallas'},
#  939: {'slackers'},
#  940: {'bomb', 'bombing', 'bombs'},
#  941: {'melancholie'},
#  942: {'Claustrophobic', 'claustrophobic'},
#  943: {'merde'},
#  944: {'inclusive'},
#  945: {'Premonition', 'premonition'},
#  946: {'Judgment', 'Judism', 'Judy', 'judge'},
#  947: {'Filmifriikki'},
#  948: {'Hollow', 'hollow'},
#  949: {'Desghidorah'},
#  950: {'Calm', 'calm', 'peace', 'peaceful'},
#  951: {'asians'},
#  952: {'trailblazing'},
#  953: {'Lighting', 'lighting'},
#  954: {'Gays', 'gays'},
#  955: {'seamless'},
#  957: {'unnecessary'},
#  958: {'ripley'},
#  959: {'WHO'},
#  960: {'mean'},
#  962: {'underwhelming'},
#  964: {'castle'},
#  965: {'Engaging', 'engaging'},
#  966: {'speed', 'speeding'},
#  968: {'Pittsburgh', 'pittsburgh'},
#  969: {'Powhatan'},
#  970: {'Borg'},
#  971: {'styling'},
#  972: {'Decadence', 'decadence', 'decadent'},
#  973: {'drew'},
#  974: {'Liberace', 'Liberia'},
#  975: {'Algeria', 'algeria'},
#  977: {'Ice', 'ice'},
#  978: {'Christmas', 'Xmas', 'christmas'},
#  979: {'jaws'},
#  981: {'Sicily'},
#  982: {'America',
#   'American',
#   'Americana',
#   'Americanized',
#   'america',
#   'american',
#   'americana',
#   'americanised'},
#  983: {'xenophobia', 'xenophobic', 'xenophoby'},
#  984: {'Remake', 'remake', 'remakes'},
#  985: {'biting'},
#  986: {'Grace', 'grace'},
#  988: {'exaggerated', 'hyperbole'},
#  989: {'Stress', 'stress'},
#  993: {'cyborg', 'cyborgs'},
#  994: {'agent', 'agents'},
#  995: {'Sappy', 'sappy'},
#  997: {'Smeat'},
#  998: {'Prohibition', 'banned', 'prohibition'},
#  999: {'Alcatraz'},
#  1002: {'Sports', 'sports'},
#  1003: {'typhus'},
#  1004: {'makeover'},
#  1006: {'pharmaceutical', 'pharmacy'},
#  1007: {'deliberate'},
#  1008: {'sorority'},
#  1009: {'alligator', 'alligators'},
#  1010: {'conquistador'},
#  1011: {'misotheistic'},
#  1012: {'cronenberg'},
#  1013: {'Monster', 'monster', 'monsterous'},
#  1014: {'flop'},
#  1015: {'drana'},
#  1016: {'15555555555'},
#  1017: {'Erin', 'Eris'},
#  1018: {'boksdrama'},
#  1020: {'revelatory'},
#  1021: {'ALCOHOLISM', 'Alcoholism', 'alcohol', 'alcoholic', 'alcoholism'},
#  1024: {'libertarian', 'libertarians'},
#  1025: {'chimpanzee'},
#  1026: {'Reverse'},
#  1027: {'1920', '1920s', '2020s'},
#  1028: {'Jacksonville', 'jackass', 'jackson', 'jacksonville'},
#  1029: {'Emotional', 'emotion', 'emotional', 'emotions'},
#  1030: {'typewriter'},
#  1031: {'Today'},
#  1032: {'Frank', 'Frankenstein', 'Frankfurt', 'frank', 'frankenstein'},
#  1033: {'Stunts', 'stunts'},
#  1034: {'eighties'},
#  1035: {'2', '2D', '2rate'},
#  1036: {'protection', 'protective'},
#  1038: {'turd'},
#  1041: {'dirty'},
#  1042: {'ATMOSPHERIC',
#   'Atmosphere',
#   'Atmospheric',
#   'atmospheirc',
#   'atmosphere',
#   'atmospheric',
#   'atmpspheric'},
#  1043: {'soothing'},
#  1044: {'orangatang'},
#  1045: {'resilience'},
#  1046: {'Ari'},
#  1047: {'opaque'},
#  1048: {'Sniper', 'sniper'},
#  1049: {'phone'},
#  1050: {'sadomasochism', 'sadomasochistic'},
#  1051: {'Clouseau', 'Clousseau'},
#  1052: {'cuts', 'cutting'},
#  1053: {'Bangkok', 'bangkok'},
#  1054: {'Egypt', 'egypt', 'egyptian', 'egyptology'},
#  1055: {'Muyahidin'},
#  1056: {'Dragon', 'dragon'},
#  1057: {'Churchill'},
#  1058: {'Arctic',
#   'Cold',
#   'Winter',
#   'arctic',
#   'blizzard',
#   'breezy',
#   'cold',
#   'freezing',
#   'frozen',
#   'snow',
#   'winter',
#   'wintry'},
#  1059: {'Coen', 'coen'},
#  1060: {'btaegeshelf', 'etaegeshelf'},
#  1061: {'Wistful', 'wistful'},
#  1062: {'headmaster'},
#  1063: {'conspriacy'},
#  1064: {'superheros'},
#  1065: {'Corruption', 'corrupt', 'corruption'},
#  1066: {'thinker'},
#  1067: {'foqam'},
#  1068: {'1950s'},
#  1069: {'Karma'},
#  1070: {'squirrels'},
#  1071: {'Contradictory'},
#  1073: {'Rus'},
#  1074: {'accessible'},
#  1075: {'Toho'},
#  1076: {'Banksy', 'bank', 'banking', 'banks'},
#  1077: {'Monk'},
#  1078: {'aspirations'},
#  1080: {'idiot', 'idiots'},
#  1081: {'Magne', 'magier'},
#  1083: {'lunatics'},
#  1084: {'Gymnastics', 'gym', 'gymnastics'},
#  1085: {'bulimia'},
#  1086: {'invisibility'},
#  1087: {'NPH'},
#  1088: {'continuity', 'perseverance', 'persistence'},
#  1089: {'Passable'},
#  1090: {'Explosion', 'Explosions', 'explodeytime', 'explosion', 'explosions'},
#  1091: {'Colors', 'color', 'colorful', 'colors', 'colourful', 'colours'},
#  1092: {'solemn'},
#  1093: {'Ontario'},
#  1094: {'Underrated', 'underrated'},
#  1095: {'Oppression', 'oppression'},
#  1096: {'Disjointed', 'detached', 'disconnected', 'disjointed', 'separation'},
#  1097: {'nerd', 'nerds', 'nerdy'},
#  1098: {'Walden'},
#  1099: {'Pampa'},
#  1100: {'vandalism'},
#  1102: {'rebels'},
#  1103: {'Minnesota', 'minnesota'},
#  1105: {'playground'},
#  1106: {'Effects', 'effects', 'theeffects'},
#  1107: {'uniforms'},
#  1108: {'Giants', 'giants'},
#  1109: {'antisocial'},
#  1110: {'balkans'},
#  1111: {'Bobo'},
#  1112: {'daaamn'},
#  1114: {'geekey'},
#  1115: {'1918'},
#  1116: {'sociology'},
#  1117: {'casal'},
#  1118: {'Timelines', 'timelines'},
#  1119: {'orcs'},
#  1120: {'cisco'},
#  1121: {'Memorable', 'memorable'},
#  1122: {'KISS', 'Kiss', 'kiss', 'kissing'},
#  1123: {'grating'},
#  1125: {'Rochkind'},
#  1126: {'starvation', 'starving'},
#  1127: {'NOTHING', 'Nothing', 'nnothing', 'nothing'},
#  1128: {'transphobia', 'transphobic'},
#  1129: {'sensous'},
#  1130: {'cannon'},
#  1131: {'ROMANTIC', 'Romantic', 'Romanticism', 'romantic'},
#  1132: {'power'},
#  1133: {'Story', 'stories', 'story', 'storyline', 'storylines'},
#  1134: {'useful'},
#  1135: {'owenWilson'},
#  1136: {'Short', 'short', 'shorts'},
#  1137: {'penthouse'},
#  1138: {'wash'},
#  1139: {'lobotomy'},
#  1140: {'auteuil'},
#  1141: {'wikus'},
#  1143: {'Persia', 'Persian', 'persia', 'persians'},
#  1145: {'Pedophilia', 'paedophilia', 'pedophilia'},
#  1146: {'TMNT', 'tmnt'},
#  ...}

# %% [markdown]
# ## Filter only releavant tags

# %%
def filter_tags(x):
    out = False
    if x in tag_set:
        out = True
    return out

def apply_cluster_tag(x):
    new_tagid = -1
    if x in tag_to_clusterid:
        new_tagid = tag_to_clusterid[x]
    return new_tagid

# Filter out relevant tags
tag_df['relevant_tags'] = tag_df.apply(lambda row: filter_tags(row['tag']),axis=1)
tag_df['new_tagid'] = tag_df.apply(lambda row: apply_cluster_tag(row['tag']),axis=1)

# %%
tag_df1 = tag_df[tag_df.relevant_tags == True]
tag_df1 = tag_df[tag_df.new_tagid != -1]

# %%
tag_df1.shape
# Out:
# (218974, 6)

# %%
tag_df1.head()
# Out:
#     userId  movieId        tag            timestamp  relevant_tags  new_tagid
# 5       65      668  bollywood  2013-05-10 01:37:56           True       1691
# 8       65     1391       mars  2013-05-10 01:40:55           True        713
# 10      65     1694      jesus  2013-05-10 01:38:45           True       2118
# 12      65     2022      jesus  2013-05-10 01:38:45           True       2118
# 13      65     2193     dragon  2013-05-10 02:01:54           True       1056

# %%
len(clusterid_to_tag)
# Out:
# 5886
